# %%
import pandas as pd

# %% [markdown]
# # load dataset

# %%
data = pd.read_csv(r'C:\Users\Hoang\Data analysis\Datasets\ufo_sighting_data.csv')
df = pd.DataFrame(data)
# Out:
# C:\Users\Hoang\AppData\Local\Temp\ipykernel_8132\1477081063.py:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r'C:\Users\Hoang\Data analysis\Datasets\ufo_sighting_data.csv')

# %% [markdown]
# # Overview data

# %%
df.head(20)
# Out:
#            Date_time                  city state/province country UFO_shape  \
# 0   10/10/1949 20:30            san marcos             tx      us  cylinder
# 1   10/10/1949 21:00          lackland afb             tx     NaN     light
# 2   10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3   10/10/1956 21:00                  edna             tx      us    circle
# 4   10/10/1960 20:00               kaneohe             hi      us     light
# 5   10/10/1961 19:00               bristol             tn      us    sphere
# 6   10/10/1965 21:00    penarth (uk/wales)            NaN      gb    circle
# 7   10/10/1965 23:45               norwalk             ct      us      disk
# 8   10/10/1966 20:00             pell city             al      us      disk
# 9   10/10/1966 21:00              live oak             fl      us      disk
# 10  10/10/1968 13:00             hawthorne             ca      us    circle
# ...

# %% [markdown]
# # Write a Pandas program to create the todays date.

# %%
print(f'Today is: {pd.Timestamp.today(tz=None)}')

# %% [markdown]
# # Write a Pandas program to calculate all the sighting days of the unidentified flying object (ufo) from current date.

# %%
df['Date_time'] = pd.to_datetime(df['Date_time'], errors='coerce')
# Out:
#                 Date_time                  city state/province country  \
# 0     1949-10-10 20:30:00            san marcos             tx      us
# 1     1949-10-10 21:00:00          lackland afb             tx     NaN
# 2     1955-10-10 17:00:00  chester (uk/england)            NaN      gb
# 3     1956-10-10 21:00:00                  edna             tx      us
# 4     1960-10-10 20:00:00               kaneohe             hi      us
# ...                   ...                   ...            ...     ...
# 80327 2013-09-09 21:15:00             nashville             tn      us
# 80328 2013-09-09 22:00:00                 boise             id      us
# 80329 2013-09-09 22:00:00                  napa             ca      us
# 80330 2013-09-09 22:20:00                vienna             va      us
# 80331 2013-09-09 23:00:00                edmond             ok      us
#
#       UFO_shape length_of_encounter_seconds described_duration_of_encounter  \
# ...

# %%
df['Date_time'].dropna()
# Out:
# 0       1949-10-10 20:30:00
# 1       1949-10-10 21:00:00
# 2       1955-10-10 17:00:00
# 3       1956-10-10 21:00:00
# 4       1960-10-10 20:00:00
#                 ...
# 80327   2013-09-09 21:15:00
# 80328   2013-09-09 22:00:00
# 80329   2013-09-09 22:00:00
# 80330   2013-09-09 22:20:00
# 80331   2013-09-09 23:00:00
# Name: Date_time, Length: 79638, dtype: datetime64[ns]

# %%
pd.Timedelta(2024,'d')
# Out:
# Timedelta('2024 days 00:00:00')

# %%
def calculate_sighting_day(from_date, now):
    """ calculate how many days from given date until now"""
    """ from_date: format to date_time column """
    """ now: pd.Timestamp.today(tz=None)"""
    return now - from_date

from_date = datetime(2013-09-09
# Out:
#   Cell In[38], line 7
#     from_date = 2013-09-09
#                      ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
