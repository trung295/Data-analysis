# %%
from pathlib import Path
import plotly.express as px
import json

# load geojson file as string
path = Path(r'C:\Users\Hoang\Data analysis\Practices\Python crash course\project\data visualization\Mapping global datasets\eq_data\eq_data_30days.geojson')
contents = path.read_text()
eq_30_days = json.loads(contents)

# rewrite file to more readable
path = Path(r'C:\Users\Hoang\Data analysis\Practices\Python crash course\project\data visualization\Mapping global datasets\eq_data\readable_eq_data_30days.geojson')
readable_eq_30 = json.dumps(eq_30_days, indent = 3)
path.write_text(readable_eq_30)

#
# Out:
# {
#    "type": "FeatureCollection",
#    "metadata": {
#       "generated": 1745119051000,
#       "url": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_month.geojson",
#       "title": "USGS Significant Earthquakes, Past Month",
#       "status": 200,
#       "api": "1.14.1",
#       "count": 17
#    },
#    "features": [
#       {
#          "type": "Feature",
#          "properties": {
#             "mag": 4.3,
#             "place": "20 km W of Beluga, Alaska",
#             "time": 1745047135928,
#             "updated": 1745118038886,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak02550duu6u",
#             "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02550duu6u.geojson",
#             "felt": 1411,
#             "cdi": 3.8,
#             "mmi": 3.527,
#             "alert": "green",
#             "status": "reviewed",
#             "tsunami": 1,
#             "sig": 664,
# ...
